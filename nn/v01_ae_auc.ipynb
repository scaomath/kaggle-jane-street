# %% [markdown]
# # Read data

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
TRAINING = True
USE_FINETUNE = False     
FOLDS = 4
SEED = 42
FOLDER = '20210118_auc'
try:
    os.mkdir(FOLDER)
except:
    pass

# %%
# %%time
train = pd.read_feather('/storage1/lu/Active/tianyang/Workspace/janestreet/train.feather')
# Out:
# CPU times: user 3.25 s, sys: 4.65 s, total: 7.89 s
# Wall time: 22.4 s

# %%
# %%time

# feature generation process seems to be different after day 85; removing the first 85 days gives better scores
train = train.query('date > 85').reset_index(drop = True) 
# less memory usage
train = train.astype({c: np.float32 for c in train.select_dtypes(include='float64').columns})
# imputation (try ffill?)
train.fillna(train.mean(),inplace=True)
# no need to predict 0 weight
train = train.query('weight > 0').reset_index(drop = True)

#train['action'] = (train['resp'] > 0).astype('int')
# multiple targets
train['action'] = ((train['resp_1'] > 0 ) &\
                   (train['resp_2'] > 0 ) &\
                   (train['resp_3'] > 0 ) &\
                   (train['resp_4'] > 0 ) &\
                   (train['resp'] > 0 )).astype('int')

features = [c for c in train.columns if 'feature' in c]
resp_cols = ['resp_1', 'resp_2', 'resp_3', 'resp', 'resp_4']

X = train[features].values
y = np.stack([(train[c] > 0).astype('int') for c in resp_cols]).T

# for imputation during forecasting
f_mean = np.mean(train[features[1:]].values, axis=0)
# Out:
# CPU times: user 4.99 s, sys: 3.54 s, total: 8.53 s
# Wall time: 8.6 s

# %% [markdown]
# ## Encoder + MLP
# The idea of using an encoder is the denoise the data. After many attempts at using a unsupervised autoencoder, the choice landed on a bottleneck encoder as this will preserve the intra-feature relations.

# %%
from tensorflow.keras.layers import Input, Dense, BatchNormalization, Dropout, Concatenate, Lambda, GaussianNoise, Activation
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers.experimental.preprocessing import Normalization
import tensorflow as tf
import numpy as np
import pandas as pd
from sklearn.model_selection import GroupKFold

from tqdm import tqdm
from random import choices

import kerastuner as kt

# %% [markdown]
# ## PurgedGroupTimeSeriesSplit

# %%
import numpy as np
from sklearn.model_selection import KFold
from sklearn.model_selection._split import _BaseKFold, indexable, _num_samples
from sklearn.utils.validation import _deprecate_positional_args

# modified code for group gaps; source
# https://github.com/getgaurav2/scikit-learn/blob/d4a3af5cc9da3a76f0266932644b884c99724c57/sklearn/model_selection/_split.py#L2243
class PurgedGroupTimeSeriesSplit(_BaseKFold):
    """Time Series cross-validator variant with non-overlapping groups.
    Allows for a gap in groups to avoid potentially leaking info from
    train into test if the model has windowed or lag features.
    Provides train/test indices to split time series data samples
    that are observed at fixed time intervals according to a
    third-party provided group.
    In each split, test indices must be higher than before, and thus shuffling
    in cross validator is inappropriate.
    This cross-validation object is a variation of :class:`KFold`.
    In the kth split, it returns first k folds as train set and the
    (k+1)th fold as test set.
    The same group will not appear in two different folds (the number of
    distinct groups has to be at least equal to the number of folds).
    Note that unlike standard cross-validation methods, successive
    training sets are supersets of those that come before them.
    Read more in the :ref:`User Guide <cross_validation>`.
    Parameters
    ----------
    n_splits : int, default=5
        Number of splits. Must be at least 2.
    max_train_group_size : int, default=Inf
        Maximum group size for a single training set.
    group_gap : int, default=None
        Gap between train and test
    max_test_group_size : int, default=Inf
        We discard this number of groups from the end of each train split
    """

    @_deprecate_positional_args
    def __init__(self,
                 n_splits=5,
                 *,
                 max_train_group_size=np.inf,
                 max_test_group_size=np.inf,
                 group_gap=None,
                 verbose=False
                 ):
        super().__init__(n_splits, shuffle=False, random_state=None)
        self.max_train_group_size = max_train_group_size
        self.group_gap = group_gap
        self.max_test_group_size = max_test_group_size
        self.verbose = verbose

    def split(self, X, y=None, groups=None):
        """Generate indices to split data into training and test set.
        Parameters
        ----------
        X : array-like of shape (n_samples, n_features)
            Training data, where n_samples is the number of samples
            and n_features is the number of features.
        y : array-like of shape (n_samples,)
            Always ignored, exists for compatibility.
        groups : array-like of shape (n_samples,)
            Group labels for the samples used while splitting the dataset into
            train/test set.
        Yields
        ------
        train : ndarray
            The training set indices for that split.
        test : ndarray
            The testing set indices for that split.
        """
        if groups is None:
            raise ValueError(
                "The 'groups' parameter should not be None")
        X, y, groups = indexable(X, y, groups)
        n_samples = _num_samples(X)
        n_splits = self.n_splits
        group_gap = self.group_gap
        max_test_group_size = self.max_test_group_size
        max_train_group_size = self.max_train_group_size
        n_folds = n_splits + 1
        group_dict = {}
        u, ind = np.unique(groups, return_index=True)
        unique_groups = u[np.argsort(ind)]
        n_samples = _num_samples(X)
        n_groups = _num_samples(unique_groups)
        for idx in np.arange(n_samples):
            if (groups[idx] in group_dict):
                group_dict[groups[idx]].append(idx)
            else:
                group_dict[groups[idx]] = [idx]
        if n_folds > n_groups:
            raise ValueError(
                ("Cannot have number of folds={0} greater than"
                 " the number of groups={1}").format(n_folds,
                                                     n_groups))

        group_test_size = min(n_groups // n_folds, max_test_group_size)
        group_test_starts = range(n_groups - n_splits * group_test_size,
                                  n_groups, group_test_size)
        for group_test_start in group_test_starts:
            train_array = []
            test_array = []

            group_st = max(0, group_test_start - group_gap - max_train_group_size)
            for train_group_idx in unique_groups[group_st:(group_test_start - group_gap)]:
                train_array_tmp = group_dict[train_group_idx]
                
                train_array = np.sort(np.unique(
                                      np.concatenate((train_array,
                                                      train_array_tmp)),
                                      axis=None), axis=None)

            train_end = train_array.size
 
            for test_group_idx in unique_groups[group_test_start:
                                                group_test_start +
                                                group_test_size]:
                test_array_tmp = group_dict[test_group_idx]
                test_array = np.sort(np.unique(
                                              np.concatenate((test_array,
                                                              test_array_tmp)),
                                     axis=None), axis=None)

            test_array  = test_array[group_gap:]
            
            
            if self.verbose > 0:
                    pass
                    
            yield [int(i) for i in train_array], [int(i) for i in test_array]

# %% [markdown]
# ### Creating the autoencoder.
# The autoencoder should aid in denoising the data. Based on [this](https://www.semanticscholar.org/paper/Deep-Bottleneck-Classifiers-in-Supervised-Dimension-Parviainen/fb86483f7573f6430fe4597432b0cd3e34b16e43) paper.

# %%
def create_autoencoder(input_dim, output_dim, noise=0.05):
    i = Input(input_dim)
    encoded = BatchNormalization()(i)
    encoded = GaussianNoise(noise)(encoded)
    encoded = Dense(64,activation='relu')(encoded)
    decoded = Dropout(0.15)(encoded)
    decoded = BatchNormalization()(decoded)
    decoded = Dense(input_dim,name='decoded')(decoded)
    x = Dense(32, activation='relu')(decoded)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)    
    x = Dense(output_dim, activation='sigmoid' ,name='label_output')(x)
    
    encoder = Model(inputs=i, outputs=encoded)
    autoencoder = Model(inputs=i, outputs=[decoded,x])
    
    autoencoder.compile(optimizer=Adam(0.001), 
                        loss={'decoded':'mse', 'label_output':'binary_crossentropy'})
    return autoencoder, encoder

# %% [markdown]
# ### Creating the MLP.

# %%
def create_model(hp,input_dim,output_dim,encoder):
    inputs = Input(input_dim)
    
    x = encoder(inputs)
    x = Concatenate()([x,inputs, x]) #use both raw and encoded features
    x = BatchNormalization()(x)
    x = Dropout(hp.Float('init_dropout',0.0,0.5))(x)
    
    for i in range(hp.Int('num_layers',1,3)):
        x = Dense(hp.Int('num_units_{i}',64,256))(x)
        x = BatchNormalization()(x)
        x = Lambda(tf.keras.activations.swish)(x)
        x = Dropout(hp.Float(f'dropout_{i}',0.0,0.5))(x)
        
    x = Dense(output_dim, activation='sigmoid')(x)
    model = Model(inputs=inputs, outputs=x)
    # previously 1e-5, 1e-4, 1e-3
    model.compile(optimizer=Adam(hp.Float('lr',0.00005,0.005,default=0.001)),
                  loss=BinaryCrossentropy(label_smoothing=hp.Float('label_smoothing',0.0,0.1)),
                  metrics=[tf.keras.metrics.AUC(name = 'auc')])
    return model

# %% [markdown]
# ### Defining and training the autoencoder.
# We add gaussian noise with mean and std from training data. After training we lock the layers in the encoder from further training.

# %%
autoencoder, encoder = create_autoencoder(X.shape[-1],y.shape[-1],noise=0.1)
if TRAINING:
    autoencoder.fit(X,(X,y),
                    epochs=1000,
                    batch_size=4096, 
                    validation_split=0.1,
                    callbacks=[EarlyStopping('val_loss',patience=10,restore_best_weights=True)])
    encoder.save_weights(f'./{FOLDER}/encoder.hdf5')
else:
    encoder.load_weights(f'./{FOLDER}/encoder.hdf5')
encoder.trainable = False
# Out:
# Epoch 1/1000
# 346/346 [==============================] - 7s 20ms/step - loss: 2.7563 - decoded_loss: 2.0293 - label_output_loss: 0.7271 - val_loss: 1.3268 - val_decoded_loss: 0.6351 - val_label_output_loss: 0.6917
# Epoch 2/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.7326 - decoded_loss: 1.0365 - label_output_loss: 0.6961 - val_loss: 1.1644 - val_decoded_loss: 0.4737 - val_label_output_loss: 0.6907
# Epoch 3/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.6385 - decoded_loss: 0.9463 - label_output_loss: 0.6922 - val_loss: 1.1004 - val_decoded_loss: 0.4106 - val_label_output_loss: 0.6898
# Epoch 4/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.6025 - decoded_loss: 0.9114 - label_output_loss: 0.6911 - val_loss: 1.0601 - val_decoded_loss: 0.3706 - val_label_output_loss: 0.6895
# Epoch 5/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.5886 - decoded_loss: 0.8977 - label_output_loss: 0.6908 - val_loss: 1.0498 - val_decoded_loss: 0.3607 - val_label_output_loss: 0.6891
# Epoch 6/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.5686 - decoded_loss: 0.8779 - label_output_loss: 0.6907 - val_loss: 1.0367 - val_decoded_loss: 0.3477 - val_label_output_loss: 0.6890
# Epoch 7/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.5590 - decoded_loss: 0.8685 - label_output_loss: 0.6905 - val_loss: 1.0235 - val_decoded_loss: 0.3346 - val_label_output_loss: 0.6889
# Epoch 8/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.5518 - decoded_loss: 0.8614 - label_output_loss: 0.6904 - val_loss: 1.0174 - val_decoded_loss: 0.3285 - val_label_output_loss: 0.6889
# Epoch 9/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.5456 - decoded_loss: 0.8552 - label_output_loss: 0.6904 - val_loss: 1.0084 - val_decoded_loss: 0.3195 - val_label_output_loss: 0.6889
# Epoch 10/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.5358 - decoded_loss: 0.8455 - label_output_loss: 0.6903 - val_loss: 1.0080 - val_decoded_loss: 0.3191 - val_label_output_loss: 0.6889
# Epoch 11/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.5329 - decoded_loss: 0.8427 - label_output_loss: 0.6902 - val_loss: 1.0006 - val_decoded_loss: 0.3118 - val_label_output_loss: 0.6889
# Epoch 12/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.5232 - decoded_loss: 0.8330 - label_output_loss: 0.6901 - val_loss: 0.9904 - val_decoded_loss: 0.3018 - val_label_output_loss: 0.6886
# Epoch 13/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.5162 - decoded_loss: 0.8261 - label_output_loss: 0.6901 - val_loss: 0.9893 - val_decoded_loss: 0.3008 - val_label_output_loss: 0.6884
# Epoch 14/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.5203 - decoded_loss: 0.8302 - label_output_loss: 0.6900 - val_loss: 0.9834 - val_decoded_loss: 0.2949 - val_label_output_loss: 0.6884
# Epoch 15/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.5147 - decoded_loss: 0.8246 - label_output_loss: 0.6900 - val_loss: 0.9817 - val_decoded_loss: 0.2932 - val_label_output_loss: 0.6885
# Epoch 16/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.5071 - decoded_loss: 0.8172 - label_output_loss: 0.6900 - val_loss: 0.9775 - val_decoded_loss: 0.2890 - val_label_output_loss: 0.6886
# Epoch 17/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.5029 - decoded_loss: 0.8130 - label_output_loss: 0.6899 - val_loss: 0.9750 - val_decoded_loss: 0.2866 - val_label_output_loss: 0.6884
# Epoch 18/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4976 - decoded_loss: 0.8078 - label_output_loss: 0.6899 - val_loss: 0.9702 - val_decoded_loss: 0.2818 - val_label_output_loss: 0.6884
# Epoch 19/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4967 - decoded_loss: 0.8069 - label_output_loss: 0.6898 - val_loss: 0.9700 - val_decoded_loss: 0.2816 - val_label_output_loss: 0.6884
# Epoch 20/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4968 - decoded_loss: 0.8070 - label_output_loss: 0.6898 - val_loss: 0.9763 - val_decoded_loss: 0.2879 - val_label_output_loss: 0.6884
# Epoch 21/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4927 - decoded_loss: 0.8029 - label_output_loss: 0.6898 - val_loss: 0.9859 - val_decoded_loss: 0.2977 - val_label_output_loss: 0.6882
# Epoch 22/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4948 - decoded_loss: 0.8050 - label_output_loss: 0.6897 - val_loss: 0.9675 - val_decoded_loss: 0.2792 - val_label_output_loss: 0.6884
# Epoch 23/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4872 - decoded_loss: 0.7975 - label_output_loss: 0.6897 - val_loss: 0.9695 - val_decoded_loss: 0.2812 - val_label_output_loss: 0.6883
# Epoch 24/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4922 - decoded_loss: 0.8025 - label_output_loss: 0.6897 - val_loss: 0.9640 - val_decoded_loss: 0.2756 - val_label_output_loss: 0.6884
# Epoch 25/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4910 - decoded_loss: 0.8013 - label_output_loss: 0.6897 - val_loss: 0.9784 - val_decoded_loss: 0.2900 - val_label_output_loss: 0.6884
# Epoch 26/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4872 - decoded_loss: 0.7975 - label_output_loss: 0.6897 - val_loss: 0.9584 - val_decoded_loss: 0.2701 - val_label_output_loss: 0.6883
# Epoch 27/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4829 - decoded_loss: 0.7933 - label_output_loss: 0.6896 - val_loss: 0.9791 - val_decoded_loss: 0.2907 - val_label_output_loss: 0.6884
# Epoch 28/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4880 - decoded_loss: 0.7984 - label_output_loss: 0.6896 - val_loss: 0.9638 - val_decoded_loss: 0.2755 - val_label_output_loss: 0.6883
# Epoch 29/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4829 - decoded_loss: 0.7933 - label_output_loss: 0.6896 - val_loss: 0.9550 - val_decoded_loss: 0.2668 - val_label_output_loss: 0.6882
# Epoch 30/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4857 - decoded_loss: 0.7961 - label_output_loss: 0.6896 - val_loss: 0.9610 - val_decoded_loss: 0.2726 - val_label_output_loss: 0.6884
# Epoch 31/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4806 - decoded_loss: 0.7910 - label_output_loss: 0.6896 - val_loss: 0.9580 - val_decoded_loss: 0.2696 - val_label_output_loss: 0.6884
# Epoch 32/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4774 - decoded_loss: 0.7878 - label_output_loss: 0.6896 - val_loss: 0.9490 - val_decoded_loss: 0.2607 - val_label_output_loss: 0.6883
# Epoch 33/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4777 - decoded_loss: 0.7882 - label_output_loss: 0.6895 - val_loss: 0.9539 - val_decoded_loss: 0.2656 - val_label_output_loss: 0.6882
# Epoch 34/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4784 - decoded_loss: 0.7889 - label_output_loss: 0.6895 - val_loss: 0.9547 - val_decoded_loss: 0.2663 - val_label_output_loss: 0.6884
# Epoch 35/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4760 - decoded_loss: 0.7865 - label_output_loss: 0.6896 - val_loss: 0.9499 - val_decoded_loss: 0.2619 - val_label_output_loss: 0.6880
# Epoch 36/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4814 - decoded_loss: 0.7919 - label_output_loss: 0.6895 - val_loss: 0.9594 - val_decoded_loss: 0.2713 - val_label_output_loss: 0.6881
# Epoch 37/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4696 - decoded_loss: 0.7800 - label_output_loss: 0.6895 - val_loss: 0.9466 - val_decoded_loss: 0.2585 - val_label_output_loss: 0.6881
# Epoch 38/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4744 - decoded_loss: 0.7850 - label_output_loss: 0.6895 - val_loss: 0.9440 - val_decoded_loss: 0.2559 - val_label_output_loss: 0.6881
# Epoch 39/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4728 - decoded_loss: 0.7833 - label_output_loss: 0.6894 - val_loss: 0.9456 - val_decoded_loss: 0.2574 - val_label_output_loss: 0.6882
# Epoch 40/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4765 - decoded_loss: 0.7870 - label_output_loss: 0.6895 - val_loss: 0.9464 - val_decoded_loss: 0.2581 - val_label_output_loss: 0.6883
# Epoch 41/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4773 - decoded_loss: 0.7878 - label_output_loss: 0.6895 - val_loss: 0.9490 - val_decoded_loss: 0.2605 - val_label_output_loss: 0.6884
# Epoch 42/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4686 - decoded_loss: 0.7792 - label_output_loss: 0.6895 - val_loss: 0.9483 - val_decoded_loss: 0.2602 - val_label_output_loss: 0.6881
# Epoch 43/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4712 - decoded_loss: 0.7817 - label_output_loss: 0.6895 - val_loss: 0.9680 - val_decoded_loss: 0.2799 - val_label_output_loss: 0.6881
# Epoch 44/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4765 - decoded_loss: 0.7871 - label_output_loss: 0.6895 - val_loss: 0.9430 - val_decoded_loss: 0.2548 - val_label_output_loss: 0.6883
# Epoch 45/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4716 - decoded_loss: 0.7822 - label_output_loss: 0.6895 - val_loss: 0.9496 - val_decoded_loss: 0.2612 - val_label_output_loss: 0.6885
# Epoch 46/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4762 - decoded_loss: 0.7868 - label_output_loss: 0.6894 - val_loss: 0.9448 - val_decoded_loss: 0.2566 - val_label_output_loss: 0.6882
# Epoch 47/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4714 - decoded_loss: 0.7820 - label_output_loss: 0.6894 - val_loss: 0.9400 - val_decoded_loss: 0.2517 - val_label_output_loss: 0.6883
# Epoch 48/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4629 - decoded_loss: 0.7735 - label_output_loss: 0.6894 - val_loss: 0.9526 - val_decoded_loss: 0.2644 - val_label_output_loss: 0.6882
# Epoch 49/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4699 - decoded_loss: 0.7805 - label_output_loss: 0.6894 - val_loss: 0.9407 - val_decoded_loss: 0.2527 - val_label_output_loss: 0.6879
# Epoch 50/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4661 - decoded_loss: 0.7767 - label_output_loss: 0.6894 - val_loss: 0.9425 - val_decoded_loss: 0.2543 - val_label_output_loss: 0.6882
# Epoch 51/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4645 - decoded_loss: 0.7751 - label_output_loss: 0.6894 - val_loss: 0.9484 - val_decoded_loss: 0.2602 - val_label_output_loss: 0.6882
# Epoch 52/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4696 - decoded_loss: 0.7803 - label_output_loss: 0.6894 - val_loss: 0.9454 - val_decoded_loss: 0.2572 - val_label_output_loss: 0.6881
# Epoch 53/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4684 - decoded_loss: 0.7790 - label_output_loss: 0.6894 - val_loss: 0.9434 - val_decoded_loss: 0.2552 - val_label_output_loss: 0.6882
# Epoch 54/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4691 - decoded_loss: 0.7798 - label_output_loss: 0.6893 - val_loss: 0.9421 - val_decoded_loss: 0.2539 - val_label_output_loss: 0.6881
# Epoch 55/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4653 - decoded_loss: 0.7760 - label_output_loss: 0.6894 - val_loss: 0.9453 - val_decoded_loss: 0.2569 - val_label_output_loss: 0.6884
# Epoch 56/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4656 - decoded_loss: 0.7762 - label_output_loss: 0.6893 - val_loss: 0.9439 - val_decoded_loss: 0.2557 - val_label_output_loss: 0.6882
# Epoch 57/1000
# 346/346 [==============================] - 6s 18ms/step - loss: 1.4656 - decoded_loss: 0.7762 - label_output_loss: 0.6894 - val_loss: 0.9466 - val_decoded_loss: 0.2583 - val_label_output_loss: 0.6883

# %% [markdown]
# ### Running CV
# Following [this notebook](https://www.kaggle.com/gogo827jz/jane-street-ffill-xgboost-purgedtimeseriescv) which use 5 PurgedGroupTimeSeriesSplit split on the dates in the training data.
#
# We add the locked encoder as the first layer of the MLP. This seems to help in speeding up the submission rather than first predicting using the encoder then using the MLP.

# %% [markdown]
# We use a Baysian Optimizer to find the optimal HPs for our model. 20 trials take about 2 hours on GPU.

# %%
class CVTuner(kt.engine.tuner.Tuner):
    def run_trial(self, trial, X, y, splits, batch_size=32, epochs=1,callbacks=None):
        val_losses = []
        for train_indices, test_indices in splits:
            X_train, X_test = [x[train_indices] for x in X], [x[test_indices] for x in X]
            y_train, y_test = [a[train_indices] for a in y], [a[test_indices] for a in y]
            if len(X_train) < 2:
                X_train = X_train[0]
                X_test = X_test[0]
            if len(y_train) < 2:
                y_train = y_train[0]
                y_test = y_test[0]
            
            model = self.hypermodel.build(trial.hyperparameters)
            hist = model.fit(X_train,y_train,
                      validation_data=(X_test,y_test),
                      epochs=epochs,
                        batch_size=batch_size,
                      callbacks=callbacks)
            
            val_losses.append([hist.history[k][-1] for k in hist.history])
        val_losses = np.asarray(val_losses)
        self.oracle.update_trial(trial.trial_id, {k:np.mean(val_losses[:,i]) for i,k in enumerate(hist.history.keys())})
        self.save_model(trial.trial_id, model)

# %%
model_fn = lambda hp: create_model(hp,X.shape[-1],y.shape[-1],encoder)

tuner = CVTuner(
        hypermodel=model_fn,
        oracle=kt.oracles.BayesianOptimization(
            objective= kt.Objective('val_auc', direction='max'),
            num_initial_points=4,
            max_trials=1))

if TRAINING:
    print('searching...')
    gkf = PurgedGroupTimeSeriesSplit(n_splits = FOLDS, group_gap=20)
    splits = list(gkf.split(y, groups=train['date'].values))
    tuner.search((X,),
                 (y,),
                 splits=splits,
                 batch_size=4096,
                 epochs=100,
                 callbacks=[EarlyStopping('val_auc', mode='max',patience=3)])
    hp = tuner.get_best_hyperparameters(1)[0]
    pd.to_pickle(hp,f'./{FOLDER}/best_hp_{SEED}.pkl')
    
    print('fitting...')
    for fold, (train_indices, test_indices) in enumerate(splits):
        model = model_fn(hp)
        X_train, X_test = X[train_indices], X[test_indices]
        y_train, y_test = y[train_indices], y[test_indices]
        model.fit(X_train, y_train,
                  validation_data=(X_test,y_test),
                  epochs=100,
                  batch_size=4096,
                  callbacks=[EarlyStopping('val_auc',mode='max',patience=10,restore_best_weights=True)])
        model.save_weights(f'./{FOLDER}/model_{SEED}_{fold}.hdf5')
        model.compile(Adam(hp.get('lr')/100), loss='binary_crossentropy')
        model.fit(X_test, y_test, epochs=3, batch_size=4096)
        model.save_weights(f'./{FOLDER}/model_{SEED}_{fold}_finetune.hdf5')
    tuner.results_summary()
    
else:
    models = []
    hp = pd.read_pickle(f'./{FOLDER}/best_hp_{SEED}.pkl')
    for f in range(FOLDS):
        model = model_fn(hp)
        if USE_FINETUNE:
            model.load_weights(f'./{FOLDER}/model_{SEED}_{f}_finetune.hdf5')
        else:
            model.load_weights(f'./{FOLDER}/model_{SEED}_{f}.hdf5')
        models.append(model)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ./untitled_project/oracle.json
# INFO:tensorflow:Reloading Tuner from ./untitled_project/tuner0.json
# searching...
# INFO:tensorflow:Oracle triggered exit
# fitting...
# Epoch 1/100
# 48/48 [==============================] - 4s 88ms/step - loss: 0.7053 - auc: 0.5163 - val_loss: 0.7333 - val_auc: 0.5231
# Epoch 2/100
# 48/48 [==============================] - 3s 72ms/step - loss: 0.6915 - auc: 0.5358 - val_loss: 0.6960 - val_auc: 0.5339
# Epoch 3/100
# 48/48 [==============================] - 3s 72ms/step - loss: 0.6905 - auc: 0.5412 - val_loss: 0.6918 - val_auc: 0.5365
# Epoch 4/100
# 48/48 [==============================] - 3s 72ms/step - loss: 0.6903 - auc: 0.5442 - val_loss: 0.6912 - val_auc: 0.5401
# Epoch 5/100
# 48/48 [==============================] - 3s 72ms/step - loss: 0.6888 - auc: 0.5503 - val_loss: 0.6909 - val_auc: 0.5415
# Epoch 6/100
# 48/48 [==============================] - 3s 72ms/step - loss: 0.6884 - auc: 0.5529 - val_loss: 0.6910 - val_auc: 0.5411
# Epoch 7/100
# 48/48 [==============================] - 3s 72ms/step - loss: 0.6877 - auc: 0.5550 - val_loss: 0.6909 - val_auc: 0.5421
# Epoch 8/100
# 48/48 [==============================] - 3s 71ms/step - loss: 0.6867 - auc: 0.5596 - val_loss: 0.6915 - val_auc: 0.5424
# Epoch 9/100
# 48/48 [==============================] - 3s 71ms/step - loss: 0.6863 - auc: 0.5602 - val_loss: 0.6914 - val_auc: 0.5401
# Epoch 10/100
# 48/48 [==============================] - 3s 72ms/step - loss: 0.6858 - auc: 0.5630 - val_loss: 0.6920 - val_auc: 0.5383
# Epoch 11/100
# 48/48 [==============================] - 3s 72ms/step - loss: 0.6852 - auc: 0.5642 - val_loss: 0.6918 - val_auc: 0.5408
# Epoch 12/100
# 48/48 [==============================] - 3s 72ms/step - loss: 0.6844 - auc: 0.5664 - val_loss: 0.6915 - val_auc: 0.5418
# Epoch 13/100
# 48/48 [==============================] - 3s 72ms/step - loss: 0.6840 - auc: 0.5672 - val_loss: 0.6925 - val_auc: 0.5413
# Epoch 14/100
# 48/48 [==============================] - 3s 71ms/step - loss: 0.6831 - auc: 0.5697 - val_loss: 0.6926 - val_auc: 0.5406
# Epoch 15/100
# 48/48 [==============================] - 3s 72ms/step - loss: 0.6831 - auc: 0.5691 - val_loss: 0.6937 - val_auc: 0.5401
# Epoch 16/100
# 48/48 [==============================] - 3s 72ms/step - loss: 0.6821 - auc: 0.5729 - val_loss: 0.6935 - val_auc: 0.5423
# Epoch 17/100
# 48/48 [==============================] - 3s 72ms/step - loss: 0.6819 - auc: 0.5734 - val_loss: 0.6952 - val_auc: 0.5399
# Epoch 18/100
# 48/48 [==============================] - 3s 72ms/step - loss: 0.6815 - auc: 0.5738 - val_loss: 0.6956 - val_auc: 0.5396
# Epoch 1/3
# 71/71 [==============================] - 3s 38ms/step - loss: 0.6915
# Epoch 2/3
# 71/71 [==============================] - 3s 38ms/step - loss: 0.6906
# Epoch 3/3
# 71/71 [==============================] - 3s 38ms/step - loss: 0.6901
# Epoch 1/100
# 118/118 [==============================] - 7s 63ms/step - loss: 0.6975 - auc: 0.5263 - val_loss: 0.6915 - val_auc: 0.5402
# Epoch 2/100
# 118/118 [==============================] - 7s 59ms/step - loss: 0.6912 - auc: 0.5400 - val_loss: 0.6903 - val_auc: 0.5416
# Epoch 3/100
# 118/118 [==============================] - 7s 59ms/step - loss: 0.6903 - auc: 0.5435 - val_loss: 0.6901 - val_auc: 0.5412
# Epoch 4/100
# 118/118 [==============================] - 7s 59ms/step - loss: 0.6896 - auc: 0.5459 - val_loss: 0.6900 - val_auc: 0.5440
# Epoch 5/100
# 118/118 [==============================] - 7s 59ms/step - loss: 0.6890 - auc: 0.5487 - val_loss: 0.6901 - val_auc: 0.5459
# Epoch 6/100
# 118/118 [==============================] - 7s 58ms/step - loss: 0.6887 - auc: 0.5502 - val_loss: 0.6903 - val_auc: 0.5448
# Epoch 7/100
# 118/118 [==============================] - 7s 59ms/step - loss: 0.6882 - auc: 0.5525 - val_loss: 0.6904 - val_auc: 0.5465
# Epoch 8/100
# 118/118 [==============================] - 7s 56ms/step - loss: 0.6878 - auc: 0.5537 - val_loss: 0.6909 - val_auc: 0.5455
# Epoch 9/100
# 118/118 [==============================] - 7s 56ms/step - loss: 0.6875 - auc: 0.5549 - val_loss: 0.6907 - val_auc: 0.5461
# Epoch 10/100
# 118/118 [==============================] - 7s 56ms/step - loss: 0.6872 - auc: 0.5560 - val_loss: 0.6907 - val_auc: 0.5440
# Epoch 11/100
# 118/118 [==============================] - 7s 56ms/step - loss: 0.6869 - auc: 0.5566 - val_loss: 0.6909 - val_auc: 0.5429
# Epoch 12/100
# 118/118 [==============================] - 7s 56ms/step - loss: 0.6864 - auc: 0.5585 - val_loss: 0.6907 - val_auc: 0.5453
# Epoch 13/100
# 118/118 [==============================] - 7s 56ms/step - loss: 0.6862 - auc: 0.5598 - val_loss: 0.6914 - val_auc: 0.5442
# Epoch 14/100
# 118/118 [==============================] - 7s 57ms/step - loss: 0.6858 - auc: 0.5608 - val_loss: 0.6908 - val_auc: 0.5455
# Epoch 15/100
# 118/118 [==============================] - 7s 56ms/step - loss: 0.6858 - auc: 0.5606 - val_loss: 0.6912 - val_auc: 0.5442
# Epoch 16/100
# 118/118 [==============================] - 7s 57ms/step - loss: 0.6856 - auc: 0.5616 - val_loss: 0.6920 - val_auc: 0.5438
# Epoch 17/100
# 118/118 [==============================] - 7s 56ms/step - loss: 0.6852 - auc: 0.5629 - val_loss: 0.6923 - val_auc: 0.5451
# Epoch 1/3
# 77/77 [==============================] - 3s 39ms/step - loss: 0.6905
# Epoch 2/3
# 77/77 [==============================] - 3s 38ms/step - loss: 0.6897
# Epoch 3/3
# 77/77 [==============================] - 3s 38ms/step - loss: 0.6893
# Epoch 1/100
# 193/193 [==============================] - 11s 58ms/step - loss: 0.6953 - auc: 0.5314 - val_loss: 0.6913 - val_auc: 0.5346
# Epoch 2/100
# 193/193 [==============================] - 11s 56ms/step - loss: 0.6906 - auc: 0.5416 - val_loss: 0.6917 - val_auc: 0.5354
# Epoch 3/100
# 193/193 [==============================] - 11s 56ms/step - loss: 0.6900 - auc: 0.5446 - val_loss: 0.6906 - val_auc: 0.5379
# Epoch 4/100
# 193/193 [==============================] - 11s 56ms/step - loss: 0.6895 - auc: 0.5470 - val_loss: 0.6911 - val_auc: 0.5378
# Epoch 5/100
# 193/193 [==============================] - 11s 56ms/step - loss: 0.6891 - auc: 0.5486 - val_loss: 0.6907 - val_auc: 0.5376
# Epoch 6/100
# 193/193 [==============================] - 11s 56ms/step - loss: 0.6887 - auc: 0.5503 - val_loss: 0.6906 - val_auc: 0.5398
# Epoch 7/100
# 193/193 [==============================] - 11s 56ms/step - loss: 0.6885 - auc: 0.5516 - val_loss: 0.6906 - val_auc: 0.5392
# Epoch 8/100
# 193/193 [==============================] - 11s 55ms/step - loss: 0.6881 - auc: 0.5529 - val_loss: 0.6910 - val_auc: 0.5387
# Epoch 9/100
# 193/193 [==============================] - 11s 56ms/step - loss: 0.6878 - auc: 0.5540 - val_loss: 0.6906 - val_auc: 0.5412
# Epoch 10/100
# 193/193 [==============================] - 11s 56ms/step - loss: 0.6877 - auc: 0.5547 - val_loss: 0.6908 - val_auc: 0.5392
# Epoch 11/100
# 193/193 [==============================] - 11s 55ms/step - loss: 0.6873 - auc: 0.5558 - val_loss: 0.6912 - val_auc: 0.5412
# Epoch 12/100
# 193/193 [==============================] - 11s 56ms/step - loss: 0.6871 - auc: 0.5566 - val_loss: 0.6911 - val_auc: 0.5403
# Epoch 13/100
# 193/193 [==============================] - 11s 55ms/step - loss: 0.6869 - auc: 0.5576 - val_loss: 0.6907 - val_auc: 0.5409
# Epoch 14/100
# 193/193 [==============================] - 11s 56ms/step - loss: 0.6867 - auc: 0.5584 - val_loss: 0.6909 - val_auc: 0.5419
# Epoch 15/100
# 193/193 [==============================] - 11s 56ms/step - loss: 0.6864 - auc: 0.5590 - val_loss: 0.6910 - val_auc: 0.5417
# Epoch 16/100
# 193/193 [==============================] - 11s 55ms/step - loss: 0.6864 - auc: 0.5596 - val_loss: 0.6907 - val_auc: 0.5416
# Epoch 17/100
# 193/193 [==============================] - 10s 53ms/step - loss: 0.6861 - auc: 0.5603 - val_loss: 0.6910 - val_auc: 0.5414
# Epoch 18/100
# 193/193 [==============================] - 10s 53ms/step - loss: 0.6860 - auc: 0.5607 - val_loss: 0.6907 - val_auc: 0.5422
# Epoch 19/100
# 193/193 [==============================] - 10s 53ms/step - loss: 0.6858 - auc: 0.5616 - val_loss: 0.6908 - val_auc: 0.5422
# Epoch 20/100
# 193/193 [==============================] - 10s 53ms/step - loss: 0.6856 - auc: 0.5620 - val_loss: 0.6912 - val_auc: 0.5413
# Epoch 21/100
# 193/193 [==============================] - 10s 53ms/step - loss: 0.6854 - auc: 0.5628 - val_loss: 0.6917 - val_auc: 0.5418
# Epoch 22/100
# 193/193 [==============================] - 10s 53ms/step - loss: 0.6853 - auc: 0.5633 - val_loss: 0.6920 - val_auc: 0.5404
# Epoch 23/100
# 193/193 [==============================] - 10s 53ms/step - loss: 0.6851 - auc: 0.5636 - val_loss: 0.6911 - val_auc: 0.5434
# Epoch 24/100
# 193/193 [==============================] - 10s 53ms/step - loss: 0.6849 - auc: 0.5647 - val_loss: 0.6918 - val_auc: 0.5419
# Epoch 25/100
# 193/193 [==============================] - 10s 53ms/step - loss: 0.6847 - auc: 0.5650 - val_loss: 0.6922 - val_auc: 0.5408
# Epoch 26/100
# 193/193 [==============================] - 10s 53ms/step - loss: 0.6847 - auc: 0.5651 - val_loss: 0.6920 - val_auc: 0.5417
# Epoch 27/100
# 193/193 [==============================] - 10s 53ms/step - loss: 0.6846 - auc: 0.5657 - val_loss: 0.6917 - val_auc: 0.5411
# Epoch 28/100
# 193/193 [==============================] - 10s 53ms/step - loss: 0.6844 - auc: 0.5661 - val_loss: 0.6919 - val_auc: 0.5425
# Epoch 29/100
# 193/193 [==============================] - 10s 53ms/step - loss: 0.6842 - auc: 0.5668 - val_loss: 0.6920 - val_auc: 0.5405
# Epoch 30/100
# 193/193 [==============================] - 10s 53ms/step - loss: 0.6842 - auc: 0.5668 - val_loss: 0.6925 - val_auc: 0.5412
# Epoch 31/100
# 193/193 [==============================] - 10s 53ms/step - loss: 0.6841 - auc: 0.5670 - val_loss: 0.6923 - val_auc: 0.5412
# Epoch 32/100
# 193/193 [==============================] - 10s 53ms/step - loss: 0.6839 - auc: 0.5678 - val_loss: 0.6923 - val_auc: 0.5403
# Epoch 33/100
# 193/193 [==============================] - 10s 52ms/step - loss: 0.6838 - auc: 0.5678 - val_loss: 0.6930 - val_auc: 0.5404
# Epoch 1/3
# 83/83 [==============================] - 3s 39ms/step - loss: 0.6928
# Epoch 2/3
# 83/83 [==============================] - 3s 38ms/step - loss: 0.6913
# Epoch 3/3
# 83/83 [==============================] - 3s 38ms/step - loss: 0.6906
# Epoch 1/100
# 276/276 [==============================] - 15s 53ms/step - loss: 0.6941 - auc: 0.5328 - val_loss: 0.6901 - val_auc: 0.5448
# Epoch 2/100
# 276/276 [==============================] - 14s 51ms/step - loss: 0.6903 - auc: 0.5422 - val_loss: 0.6892 - val_auc: 0.5481
# Epoch 3/100
# 276/276 [==============================] - 14s 49ms/step - loss: 0.6897 - auc: 0.5448 - val_loss: 0.6890 - val_auc: 0.5500
# Epoch 4/100
# 276/276 [==============================] - 13s 49ms/step - loss: 0.6894 - auc: 0.5465 - val_loss: 0.6893 - val_auc: 0.5499
# Epoch 5/100
# 276/276 [==============================] - 13s 49ms/step - loss: 0.6891 - auc: 0.5483 - val_loss: 0.6890 - val_auc: 0.5497
# Epoch 6/100
# 276/276 [==============================] - 14s 49ms/step - loss: 0.6888 - auc: 0.5493 - val_loss: 0.6889 - val_auc: 0.5502
# Epoch 7/100
# 276/276 [==============================] - 14s 50ms/step - loss: 0.6886 - auc: 0.5508 - val_loss: 0.6892 - val_auc: 0.5509
# Epoch 8/100
# 276/276 [==============================] - 14s 50ms/step - loss: 0.6883 - auc: 0.5518 - val_loss: 0.6884 - val_auc: 0.5532
# Epoch 9/100
# 276/276 [==============================] - 14s 49ms/step - loss: 0.6881 - auc: 0.5526 - val_loss: 0.6886 - val_auc: 0.5530
# Epoch 10/100
# 276/276 [==============================] - 14s 49ms/step - loss: 0.6879 - auc: 0.5535 - val_loss: 0.6888 - val_auc: 0.5515
# Epoch 11/100
# 276/276 [==============================] - 14s 49ms/step - loss: 0.6877 - auc: 0.5543 - val_loss: 0.6889 - val_auc: 0.5515
# Epoch 12/100
# 276/276 [==============================] - 14s 49ms/step - loss: 0.6875 - auc: 0.5549 - val_loss: 0.6888 - val_auc: 0.5504
# Epoch 13/100
# 276/276 [==============================] - 14s 49ms/step - loss: 0.6874 - auc: 0.5555 - val_loss: 0.6889 - val_auc: 0.5507
# Epoch 14/100
# 276/276 [==============================] - 14s 49ms/step - loss: 0.6871 - auc: 0.5568 - val_loss: 0.6891 - val_auc: 0.5502
# Epoch 15/100
# 276/276 [==============================] - 14s 49ms/step - loss: 0.6871 - auc: 0.5565 - val_loss: 0.6892 - val_auc: 0.5493
# Epoch 16/100
# 276/276 [==============================] - 14s 49ms/step - loss: 0.6868 - auc: 0.5576 - val_loss: 0.6889 - val_auc: 0.5522
# Epoch 17/100
# 276/276 [==============================] - 13s 49ms/step - loss: 0.6867 - auc: 0.5582 - val_loss: 0.6892 - val_auc: 0.5514
# Epoch 18/100
# 276/276 [==============================] - 14s 49ms/step - loss: 0.6865 - auc: 0.5583 - val_loss: 0.6889 - val_auc: 0.5528
# Epoch 1/3
# 90/90 [==============================] - 3s 38ms/step - loss: 0.6888
# Epoch 2/3
# 90/90 [==============================] - 3s 38ms/step - loss: 0.6884
# Epoch 3/3
# 90/90 [==============================] - 3s 39ms/step - loss: 0.6882
# Results summary
# Results in ./untitled_project
# Showing 10 best trials
# Objective(name='val_auc', direction='max')
# Trial summary
# Hyperparameters:
# init_dropout: 0.18995832591202738
# num_layers: 3
# num_units_{i}: 230
# dropout_0: 0.40612487180695417
# lr: 0.014189735319630607
# label_smoothing: 0.0497230052105928
# dropout_1: 0.4214070011363495
# dropout_2: 0.04391242201646989
# Score: 0.5444364994764328
# Trial summary
# Hyperparameters:
# init_dropout: 0.14097608379003723
# num_layers: 3
# num_units_{i}: 212
# dropout_0: 0.4050569173669017
# lr: 0.01123263272490698
# label_smoothing: 0.09100553994320032
# dropout_1: 0.0908311561987824
# dropout_2: 0.2859266723120435
# Score: 0.5441504120826721
# Trial summary
# Hyperparameters:
# init_dropout: 0.1042807773967978
# num_layers: 3
# num_units_{i}: 178
# dropout_0: 0.46057190223178246
# lr: 0.010640625405212314
# label_smoothing: 0.07081315688075711
# dropout_1: 0.21745709754474357
# dropout_2: 0.08509425389526956
# Score: 0.5437593460083008
# Trial summary
# Hyperparameters:
# init_dropout: 0.0
# num_layers: 3
# num_units_{i}: 88
# dropout_0: 0.4645500844338476
# lr: 0.026942064786796012
# label_smoothing: 0.0421283471963375
# dropout_1: 0.0
# dropout_2: 0.0
# Score: 0.543676346540451
# Trial summary
# Hyperparameters:
# init_dropout: 0.419166699935898
# num_layers: 2
# num_units_{i}: 255
# dropout_0: 0.16269569130397327
# lr: 0.006082310259753166
# label_smoothing: 0.049965291197920716
# dropout_1: 0.24704847639686311
# dropout_2: 0.39084623004848984
# Score: 0.5433022975921631
# Trial summary
# Hyperparameters:
# init_dropout: 0.05425995125813517
# num_layers: 3
# num_units_{i}: 209
# dropout_0: 0.42675635123165795
# lr: 0.025745639944573854
# label_smoothing: 0.054497023409918945
# dropout_1: 0.3703141878863253
# dropout_2: 0.07586272016187365
# Score: 0.5432068854570389
# Trial summary
# Hyperparameters:
# init_dropout: 0.4342463689711236
# num_layers: 2
# num_units_{i}: 161
# dropout_0: 0.001181344221912295
# lr: 0.03526792177335217
# label_smoothing: 0.009873545192752409
# dropout_1: 0.22679531046564289
# dropout_2: 0.22195852880880906
# Score: 0.5431855171918869
# Trial summary
# Hyperparameters:
# init_dropout: 0.0554445254005399
# num_layers: 3
# num_units_{i}: 253
# dropout_0: 0.4201492339654886
# lr: 0.04415122413738315
# label_smoothing: 0.07611912914119233
# dropout_1: 0.14650936615657612
# dropout_2: 0.27917489815708707
# Score: 0.5429448187351227
# Trial summary
# Hyperparameters:
# init_dropout: 0.12486866822777909
# num_layers: 2
# num_units_{i}: 245
# dropout_0: 0.4269515129813681
# lr: 0.02212796897285649
# label_smoothing: 0.04145472375716604
# dropout_1: 0.47124165803107515
# dropout_2: 0.36979819727977487
# Score: 0.5421780943870544
# Trial summary
# Hyperparameters:
# init_dropout: 0.0
# num_layers: 3
# num_units_{i}: 107
# dropout_0: 0.2021515660523483
# lr: 0.06211731075536136
# label_smoothing: 0.06381636544441165
# dropout_1: 0.0
# dropout_2: 0.0
# Score: 0.541090801358223

# %% [markdown]
# ## Submission

# %%
import os
import sys
import inspect
# for importing janestreet locally
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir) 

import janestreet

# %%
if not TRAINING:
    f = np.median
    models = models[-2:]
    env = janestreet.make_env()
    th = 0.5
    for (test_df, pred_df) in tqdm(env.iter_test()):
        if test_df['weight'].item() > 0:
            x_tt = test_df.loc[:, features].values
            if np.isnan(x_tt[:, 1:].sum()):
                x_tt[:, 1:] = np.nan_to_num(x_tt[:, 1:]) + np.isnan(x_tt[:, 1:]) * f_mean
            pred = np.mean([model(x_tt, training = False).numpy() for model in models],axis=0)
            pred = f(pred)
            pred_df.action = np.where(pred >= th, 1, 0).astype(int)
        else:
            pred_df.action = 0
        env.predict(pred_df)
